# %%
a=["stalls","circle","upperclass","box"]
s=input("Type of seat:")
pm=input("Payment mode:")
if pm=="cash":
  if s in a[0]:
    dis=625*0.1;
    bill=625-dis
  elif s in a[1]:
    dis=750*0.1
    bill=750-dis
  elif s in a[2]:
    dis=850*0.1
    bill=850-dis
  elif s in a[3]:
    dis=1000*0.1
    bill=1000-dis
else:
   if s in a[0]:
    dis=625*0.05;
    bill=625-dis
   elif s in a[1]:
    dis=750*0.05
    bill=750-dis
   elif s in a[2]:
    dis=850*0.05
    bill=850-dis
   elif s in a[3]:
    dis=1000*0.05
    bill=1000-dis
print(f"cost of ticket {bill}")
# Out:
# Type of seat:circle
# Payment mode:cash
# cost of ticket 675.0
