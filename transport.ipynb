# %%
print("Distance to be travel:")
d=int(input())
print("Weight of the goods:")
w=int(input())
if d>=500:
  if w>=100:
    c=5*d
  if w>=10 and w<100:
    c=6*d
  if w<10:
    c=7*d
if d<500:
  if w>=100:
    c=8*d
  if w<100:
    c=5*d
print(f"Amount to be charged:{c}/-")
# Out:
# Distance to be travel:
